# %%
url = 'https://id.wikipedia.org/wiki/Halaman_Utama'

# %%
import requests

# %%
#membuat permintaan dan cek tiap objek:
r = requests.get(url)
type(r)
# Out:
# requests.models.Response

# %%
requests?
# Out:
# Type:        module
# String form: <module 'requests' from 'C:\\Users\\Aria Pratama\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\requests\\__init__.py'>
# File:        c:\users\aria pratama\appdata\local\programs\python\python39\lib\site-packages\requests\__init__.py
# Docstring:
# Requests HTTP Library
# ~~~~~~~~~~~~~~~~~~~~~
#
# Requests is an HTTP library, written in Python, for human beings.
# Basic GET usage:
#
#    >>> import requests
#    >>> r = requests.get('https://www.python.org')
#    >>> r.status_code
#    200
#    >>> b'Python is a programming language' in r.content
#    True
#
# ... or POST:
#
#    >>> payload = dict(key1='value1', key2='value2')
#    >>> r = requests.post('https://httpbin.org/post', data=payload)
#    >>> print(r.text)
#    {
#      ...
#      "form": {
#        "key1": "value1",
#        "key2": "value2"
#      },
#      ...
#    }
#
# The other HTTP methods are supported - see `requests.api`. Full documentation
# ...

# %%
#ekstrak html dari objek response dan cetak
html=r.text
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="id" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Wikipedia bahasa Indonesia, ensiklopedia bebas</title>
# ...

# %%
# Mengimpor BeautifulSoup dari bs4
from bs4 import BeautifulSoup

#Membuat Objek BeautifulSoup dari HTML
soup = BeautifulSoup(html, "html5lib")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#melihat judul dari data
soup.title
# Out:
# <title>Wikipedia bahasa Indonesia, ensiklopedia bebas</title>

# %%
#menampilkan judul sebagai string
soup.title.string
# Out:
# 'Wikipedia bahasa Indonesia, ensiklopedia bebas'

# %%
#mengambil semua url yang ada dalam tag <a> sebanyak 8
soup.findAll('a')[:8]
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Loncat ke navigasi</a>,
#  <a class="mw-jump-link" href="#searchInput">Loncat ke pencarian</a>,
#  <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a>,
#  <a href="/wiki/Ensiklopedia" title="Ensiklopedia">ensiklopedia</a>,
#  <a href="/wiki/Isi_bebas" title="Isi bebas">bebas</a>,
#  <a href="/wiki/Wikipedia:Pengantar" title="Wikipedia:Pengantar">bisa disunting oleh siapa saja</a>,
#  <a href="/wiki/Istimewa:Statistik" title="Istimewa:Statistik">608.277 artikel</a>]

# %%
# mengambil semua teks pada halaman webw
text = soup.get_text()
print(text)
# Out:
# Wikipedia bahasa Indonesia, ensiklopedia bebas
# ...

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ARIAPR~1\AppData\Local\Temp/ipykernel_11352/1462503502.py in <module>
#       1 import nltk
# ----> 2 nltk.download()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     760             if download_dir is not None:
#     761                 self._download_dir = download_dir
# --> 762             self._interactive_download()
#     763             return True
#     764
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\downloader.py in _interactive_download(self)
#    1110         if TKINTER:
#    1111             try:
# -> 1112                 DownloaderGUI(self).mainloop()
# ...

# %%
#import paket regex
import re

#Definisikan sentence
sentence = 'about a century ago after the American and French Revolutions and the Napoleonic wars'

# Definisikan Regex
ps = 'a\w+' #mencari semua kata yang berawalan huruf a pada variabel sentence

#Mencari semua kata di sentence yang cocok dengan regex kemudian cetak sentence
re.findall(ps, sentence)
# Out:
# ['about', 'ago', 'after', 'an', 'and', 'and', 'apoleonic', 'ars']

# %%
re.findall('\w+', sentence) # mengekstrak semua kata
# Out:
# ['about',
#  'a',
#  'century',
#  'ago',
#  'after',
#  'the',
#  'American',
#  'and',
#  'French',
#  'Revolutions',
#  'and',
#  'the',
#  'Napoleonic',
#  'wars']

# %%
#mencari semua kata di text string 
tokens = re.findall('\w+', text)
tokens[:8]
# Out:
# ['Wikipedia',
#  'bahasa',
#  'Indonesia',
#  'ensiklopedia',
#  'bebas',
#  'document',
#  'documentElement',
#  'className']

# %%
# Impor RegexpTokenizer dari nltk.tokenize
from nltk.tokenize import RegexpTokenizer

#Buat tokenizer
tokenizer = RegexpTokenizer('\w+')

#Buat tokens
tokens=tokenizer.tokenize(text)
tokens[:8]
# Out:
# ['Wikipedia',
#  'bahasa',
#  'Indonesia',
#  'ensiklopedia',
#  'bebas',
#  'document',
#  'documentElement',
#  'className']

# %%
#Menginisialisasi ke dalam list
words = []

#Loop dari list tokens dan buat huruf kecil/lower case
for word in tokens:
    words.append(word.lower())
    
#Cetak beberapa
words[:8]
# Out:
# ['wikipedia',
#  'bahasa',
#  'indonesia',
#  'ensiklopedia',
#  'bebas',
#  'document',
#  'documentelement',
#  'classname']

# %%
#impor modul nltk
import nltk
nltk.download('stopwords')

#Get english stopwords and print some of them
sw = nltk.corpus.stopwords.words('english')
sw[:5]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ARIAPR~1\AppData\Local\Temp/ipykernel_11352/3740550621.py in <module>
#       1 #impor modul nltk
# ----> 2 import nltk
#       3 nltk.download('stopwords')
#       4
#       5 #Get english stopwords and print some of them
#
# ModuleNotFoundError: No module named 'nltk'

# %%
#Menginisialisasi ke dalam list
words_ns = []

#Tambahkan ke words_ns semua kata yang ada dalam words tetapi tidak dalam sw
for word in words:
    if word not in sw:
        words_ns.append(word)
    
#Cetak beberapa
words_ns[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ARIAPR~1\AppData\Local\Temp/ipykernel_11352/2520101247.py in <module>
#       4 #Tambahkan ke words_ns semua kata yang ada dalam words tetapi tidak dalam sw
#       5 for word in words:
# ----> 6     if word not in sw:
#       7         words_ns.append(word)
#       8
#
# NameError: name 'sw' is not defined

# %%
#Import datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

#Figures inline dan setting style visualisasi
# %matplotlib inline
sns.set()

# Buat frekuensi distribusi dan plot 25 kata
freqdist1 = nltk.FreqDist(words_ns)
freqdist1.plot(25)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
